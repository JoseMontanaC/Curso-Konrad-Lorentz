# %%
x=rnorm(1000000,0,1)
y=rnorm(1000000,0,1)

# %%
plot(x,y)
# Out:
# plot without title

# %% [markdown]
# Codispersión, coeficiente para determinar que tan similar son 2 imagenes
#
# $$\rho_{xy}=\frac{E[((x(s+h)-x(s))(y(s+h)-y(s))]}{\sqrt{E[(x(s+h)-x(s)]^2E[(y(s+h)-y(s)]^2}}$$
#
# ¿Qué hay en común entre $\rho{xy}$ y $\rho$ ?
#
# ¿qué diferencia tienen estos dos?
#
# ¿como se estima $\rho{xy}(n)$ ?

# %% [markdown]
# Revisar el coeficiente de comovimiento, mide como está variando una serie en el timepo con respecto a otra

# %%
install.packages("geoR")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘RandomFieldsUtils’, ‘splancs’, ‘RandomFields’

# %% [markdown]
# Mirar que es un mapa de codispersión, para una imagen se calcula la codispersión punto a punto.

# %%
library(geoR)
# Out:
# Warning message:
# “no DISPLAY variable so Tk is not available”--------------------------------------------------------------
#  Analysis of Geostatistical Data
#  For an Introduction to geoR go to http://www.leg.ufpr.br/geoR
#  geoR version 1.7-5.2 (built on 2016-05-02) is now loaded
# --------------------------------------------------------------

# %%
plot(s100)
# Out:
# Plot with title “”
